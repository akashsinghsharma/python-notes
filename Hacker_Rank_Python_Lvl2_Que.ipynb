# %% [markdown]
# <a href="https://colab.research.google.com/github/akashsinghsharma/python-notes/blob/main/Hacker_Rank_Python_Lvl2_Que.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Mistake tracking sheet](https://docs.google.com/spreadsheets/d/1LQCWr4zhEKB8xByfHP0SZ5HrqTUvZPoeXE0igCITMvM/edit#gid=0)

# %% [markdown]
# ---
#
#
# An extra day is added to the calendar almost every four years as February 29, and the day is called a leap day. It corrects the calendar for the fact that our planet takes approximately 365.25 days to orbit the sun. A leap year contains a leap day.
#
# In the Gregorian calendar, three conditions are used to identify leap years:
#
# The year can be evenly divided by 4, is a leap year, unless:
# The year can be evenly divided by 100, it is NOT a leap year, unless:
# The year is also evenly divisible by 400. Then it is a leap year.
# This means that in the Gregorian calendar, the years 2000 and 2400 are leap years, while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years. Source
#
# Task
#
# Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.
#
# Note that the code stub provided reads from STDIN and passes arguments to the is_leap function. It is only necessary to complete the is_leap function.
#
# ---

# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# Given the participants' score sheet for your University Sports Day, you are required to find the runner-up score. You are given n scores. Store them in a list and find the score of the runner-up.
#
# ---

# %% [markdown]
# ---
# https://www.hackerrank.com/challenges/python-lists/problem?isFullScreen=true
#
# ---
# Note: Avoid silly mistake.

# %% [markdown]
# ---
#
# https://www.hackerrank.com/challenges/py-check-strict-superset/problem?isFullScreen=true&h_r=next-challenge&h_v=zen&h_r=next-challenge&h_v=zen
#
# ---

# %% [markdown]
# ---
#
# https://www.hackerrank.com/challenges/swap-case/problem?isFullScreen=true
#
#
# ---

# %% [markdown]
# ---
#
#
#
# ---
