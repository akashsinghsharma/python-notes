# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkivani/python-notes/blob/main/Ravi_Ranjan_Class_EDA_on_IMDB_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# ## As a data scientist, you have to first explore the data and check its sanity.
#
# **Few basic analysis**
# 1. ### <b> Which are the movies with the third-lowest and third-highest budget?
# 2. ### <b> What is the average number of words in movie titles between the years 2000-2005?
# 3. ### <b> What is the most common Genre for Vin Diesel and Emma Watson movies?
# 4. ### <b> Which are the movies with the most and least earned revenue?
# 5. ### <b> What is the average runtime of movies in the year 2006?
#
# ## Further, you have to answer the following questions:
# 1. ### <b> Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.</b>
# 2. ### <b>This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)? </b>
# 3. ### <b> Find out the unique genres of movies in this dataset.</b>
# 4. ### <b> Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI? </b>
# 5. ### <b> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>
# 6. ### <b>Top 3 directors prefer which actors the most? </b>

# %% [markdown]
# # Data Exploration

# %%
# Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read csv data in panda dataframe
# path='/content/drive/MyDrive/Datasets/imdb_data.csv'
# imdb_df = pd.read_csv(path,index_col=0)

file_path ='/content/drive/MyDrive/AlmaBetter/imdb_data.csv'
imdb_df=pd.read_csv(file_path)

# %%
# shape of pandas dataframe
imdb_df.shape
# Out:
# (3000, 24)

# %%
# view first 5 rows of pandas dataframe
imdb_df.head()
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2   3                                                NaN  3,300,000.00
# 3   4                                                NaN  1,200,000.00
# 4   5                                                NaN           NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2   3                                                NaN  3,300,000.00
# 3   4                                                NaN  1,200,000.00
# 4   5                                                NaN           NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
#adding new column

imdb_df['Profit_Loss']= imdb_df['revenue']-imdb_df['budget']

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2   3                                                NaN  3,300,000.00
# 3   4                                                NaN  1,200,000.00
# 4   5                                                NaN           NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df[imdb_df['Profit_Loss']==imdb_df['Profit_Loss'].max()]
# Out:
#         id                              belongs_to_collection         budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou... 190,000,000.00
#
#                               genres                  homepage    imdb_id  \
# 1761  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#      original_language original_title  \
# 1761                en      Furious 7
#
#                                                overview  popularity  \
# 1761  Deckard Shaw seeks revenge against Dominic Tor...       27.28
#
#                            poster_path  \
# 1761  /dCgm7efXDmiABSdWDHBDBx2jwmn.jpg
#
#                                    production_companies  \
# 1761  [{'name': 'Universal Pictures', 'id': 33}, {'n...
#
#                                    production_countries release_date  runtime  \
# 1761  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       4/1/15   137.00
#
# ...

# %%
imdb_df[imdb_df['Profit_Loss'] == imdb_df['Profit_Loss'].min()]
# Out:
#         id belongs_to_collection     budget  \
# 2623  2624                   NaN  197471676
#
#                                                  genres homepage    imdb_id  \
# 2623  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      NaN  tt2239822
#
#      original_language                               original_title  \
# 2623                en  Valerian and the City of a Thousand Planets
#
#                                                overview  popularity  \
# 2623  In the 28th century, Valerian and Laureline ar...   15.262706
#
#                            poster_path                  production_companies  \
# 2623  /8L7FE3bXjN98BcmKANzrL9WwKsK.jpg  [{'name': 'EuropaCorp', 'id': 6896}]
#
#                           production_countries release_date  runtime  \
# 2623  [{'iso_3166_1': 'FR', 'name': 'France'}]      7/20/17    137.0
#
#                                        spoken_languages    status tagline  \
# ...

# %%
# get the basic info of each columns with not null rows and datatype
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 2188 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
# print the column name
print(imdb_df.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Profit_Loss'],
#       dtype='object')

# %%
# get all the categorical columns name
cat_cols = list(imdb_df.select_dtypes(include='object').columns)
print(f'Categorical columns: {cat_cols}')
# Out:
# Categorical columns: ['belongs_to_collection', 'genres', 'homepage', 'imdb_id', 'original_language', 'original_title', 'overview', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords', 'cast', 'crew']

# %%
imdb_df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#         Profit_Loss
# count  3.000000e+03
# mean   4.419452e+07
# std    1.123274e+08
# min   -1.074474e+08
# 25%    1.795200e+04
# 50%    6.121122e+06
# 75%    4.143293e+07
# max    1.316249e+09

# %%
# get all the continuous columns name
num_cols = list(imdb_df.select_dtypes(exclude='object').columns)
print(f'Continuous columns: {num_cols}')
# Out:
# Continuous columns: ['id', 'budget', 'popularity', 'runtime', 'revenue', 'Profit_Loss']

# %%
#describe all the columns of not object type
pd.set_option('float_format', '{:,.2f}'.format)
imdb_df.describe(exclude='object')
# Out:
#             id         budget  popularity  runtime          revenue  \
# count 3,000.00       2,188.00    3,000.00 2,986.00         3,000.00
# mean  1,500.50  30,893,054.08        8.46   108.29    66,725,851.89
# std     866.17  40,267,851.34       12.10    21.04   137,532,326.34
# min       1.00           1.00        0.00    11.00             1.00
# 25%     750.75   5,150,000.00        4.02    94.00     2,379,808.25
# 50%   1,500.50  16,000,000.00        7.37   104.00    16,807,068.00
# 75%   2,250.25  40,000,000.00       10.89   118.00    68,919,203.50
# max   3,000.00 380,000,000.00      294.34   338.00 1,519,557,910.00
#
#            Profit_Loss
# count         2,188.00
# mean     56,072,990.93
# std     128,585,760.16
# min    -107,447,384.00
# 25%      -1,606,973.25
# 50%      10,344,173.50
# 75%      61,911,567.50
# max   1,316,249,360.00

# %%
#describe all the columns
imdb_df.describe(include='object')
# Out:
#                                     belongs_to_collection  \
# count                                                 604
# unique                                                422
# top     [{'id': 645, 'name': 'James Bond Collection', ...
# freq                                                   16
#
#                                genres                           homepage  \
# count                            2993                                946
# unique                            872                                941
# top     [{'id': 18, 'name': 'Drama'}]  http://www.transformersmovie.com/
# freq                              266                                  4
#
#           imdb_id original_language original_title  \
# count        3000              3000           3000
# unique       3000                36           2975
# top     tt2637294                en         Joshua
# freq            1              2575              2
#
# ...

# %%
#Find number of rows that are null in each columns
imdb_df.isna().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# Profit_Loss                 0
# dtype: int64

# %%
imdb_df['budget'].min()
# Out:
# 0

# %% [markdown]
# ##After reading all Qs. now subsetting out columns neceesary for answering the question in order to get proper insights

# %%
imdb_df.replace(0,np.nan, inplace=True)
imdb_df.isna().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                    812
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                    14
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# Profit_Loss               820
# dtype: int64

# %%
imdb_df['budget'].min()
# Out:
# 1.0

# %%
imdb_df['homepage'].isnull()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998    False
# 2999    False
# Name: homepage, Length: 3000, dtype: bool

# %%
#Dropping columns
df_new=imdb_df.drop(['belongs_to_collection', 'homepage', 'imdb_id', 'overview', 'popularity',
       'poster_path', 'production_companies', 'production_countries',
       'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
       'title', 'Keywords'],axis=1)
#Replace 0 to NaN
df_new.replace(0,np.nan, inplace=True) 

#Fixing missing values (of columns of interest) to mean of data
df_new["budget"]=df_new["budget"].fillna(np.mean(df_new["budget"]))
df_new["revenue"]=df_new["revenue"].fillna(np.mean(df_new["revenue"]))

df_new.head()
# Out:
#    id        budget                                             genres  \
# 0   1 14,000,000.00                     [{'id': 35, 'name': 'Comedy'}]
# 1   2 40,000,000.00  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3  3,300,000.00                      [{'id': 18, 'name': 'Drama'}]
# 3   4  1,200,000.00  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5 30,893,054.08  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# ...

# %%
df_new.shape
# Out:
# (3000, 9)

# %%
df_new.columns
# Out:
# Index(['id', 'budget', 'genres', 'original_language', 'original_title', 'cast',
#        'crew', 'revenue', 'Profit_Loss'],
#       dtype='object')

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3000 non-null   int64
#  1   budget             3000 non-null   float64
#  2   genres             2993 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
#  8   Profit_Loss        2180 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 211.1+ KB

# %%
df_new.isna().sum()
# Out:
# id                     0
# budget                 0
# genres                 7
# original_language      0
# original_title         0
# cast                  13
# crew                  16
# revenue                0
# Profit_Loss          820
# dtype: int64

# %%
columns_to_keep= ['budget', 'genres','original_language', 'original_title','cast', 'crew', 'revenue']

# %%
#find all the row indexes for which cast is not null
df_new.loc[~df_new['cast'].isna(),'cast']
# Out:
# 0       [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1       [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2       [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3       [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4       [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#                               ...
# 2995    [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996    [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997    [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998    [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999    [{'cast_id': 2, 'character': 'Nathan Harper', ...
# Name: cast, Length: 2987, dtype: object

# %%
df_new.loc[1,'genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]"

# %%
type(df_new.loc[1,'genres'])
# Out:
# str

# %% [markdown]
# ##Converting the string values to proper list and we are using it on columns --> cast crew genres
# ## Converting only non null string

# %%
def convert_to_list(str):
  return eval(str)

# %%
#apply the above function only on non null values in genres column
df_new.loc[~df_new['genres'].isna(),'genres']= imdb_df.loc[~imdb_df['genres'].isna(),'genres'].apply(convert_to_list)

# %%
#apply the above function only on non null values in cast column
df_new.loc[~df_new['cast'].isna(),'cast']= imdb_df.loc[~imdb_df['cast'].isna(),'cast'].apply(convert_to_list)

# %%
#apply the above function only on non null values in crew column
df_new.loc[~df_new['crew'].isna(),'crew']= imdb_df.loc[~imdb_df['crew'].isna(),'crew'].apply(convert_to_list)

# %% [markdown]
# **1.Which are the movies with the third-lowest and third-highest budget?**

# %%
sort_low=df_new.sort_values("budget", ascending=True)
sort_low.head(3)
#Third lowest budget=1.0	; Movie Name= Lost & Found
# Out:
#         id  budget                                             genres  \
# 1346  1347    1.00                      [{'id': 18, 'name': 'Drama'}]
# 695    696    1.00  [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...
# 2255  2256    1.00  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#      original_language original_title  \
# 1346                en   East of Eden
# 695                 hi      Tere Naam
# 2255                en   Lost & Found
#
#                                                    cast  \
# 1346  [{'cast_id': 4, 'character': 'Caleb Trask', 'c...
# 695   [{'cast_id': 3, 'character': 'Radhe Mohan', 'c...
# 2255  [{'cast_id': 1, 'character': 'Dylan Ramsey', '...
#
#                                                    crew  revenue  Profit_Loss
# 1346  [{'credit_id': '52fe4228c3a36847f800869d', 'de...        5         4.00
# 695   [{'credit_id': '52fe491ec3a36847f8189cfb', 'de...        2         1.00
# ...

# %%
sort_high=df_new.sort_values("budget")
sort_high.head(3)
#Third highest budget 280,000,000.00; Movie name= Avengers: Age of Ultron
# Out:
#         id  budget                                             genres  \
# 1346  1347    1.00                      [{'id': 18, 'name': 'Drama'}]
# 695    696    1.00  [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...
# 2255  2256    1.00  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#      original_language original_title  \
# 1346                en   East of Eden
# 695                 hi      Tere Naam
# 2255                en   Lost & Found
#
#                                                    cast  \
# 1346  [{'cast_id': 4, 'character': 'Caleb Trask', 'c...
# 695   [{'cast_id': 3, 'character': 'Radhe Mohan', 'c...
# 2255  [{'cast_id': 1, 'character': 'Dylan Ramsey', '...
#
#                                                    crew  revenue  Profit_Loss
# 1346  [{'credit_id': '52fe4228c3a36847f800869d', 'de...        5         4.00
# 695   [{'credit_id': '52fe491ec3a36847f8189cfb', 'de...        2         1.00
# ...

# %% [markdown]
# **2. What is the average number of words in movie titles between the years 2000-2005?**

# %%
df_year=pd.read_csv(file_path)
# df_year['date'] = pd.to_datetime(df_year['release_date'],format='%m/%d/%y')
df_year['year'] = pd.DatetimeIndex(pd.to_datetime(df_year['release_date'],format='%m/%d/%y')).year

# %%
df_year.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
# here index col is year of release
df_year.set_index("year", inplace = True)

# %%
df_year.head(2)
# Out:
#       id                              belongs_to_collection    budget  \
# year
# 2015   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2004   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                                  genres homepage    imdb_id  \
# year
# 2015                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 2004  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#      original_language                            original_title  \
# year
# 2015                en                    Hot Tub Time Machine 2
# 2004                en  The Princess Diaries 2: Royal Engagement
#
#                                                overview  popularity  \
# year
# 2015  When Lou, who has become the "father of the In...        6.58
# 2004  Mia Thermopolis is now a college graduate and ...        8.25
#
#                            poster_path  \
# year
# ...

# %%
sort_year=df_year.loc[[2000,2001,2002,2003,2004,2005],["original_title"]] #rows of interest and column of interest
sort_year #show df
#Here there are 482 rows ie 482 is the total number of movies
# Out:
#                  original_title
# year
# 2000                 About Adam
# 2000        The Next Best Thing
# 2000  Kandukondain Kandukondain
# 2000             Romeo Must Die
# 2000                   The Gift
# ...                         ...
# 2005                   Sky High
# 2005                The Matador
# 2005                     Robots
# 2005                 BloodRayne
# 2005          Alone in the Dark
#
# [482 rows x 1 columns]

# %%
movie = "Alone in the Dark"
len(movie.split())
# Out:
# 4

# %%
#pseudo code

# count_list = []
# for item in sort_year.original_title:
#   count_list.append(len((item.split())))
# len of count_list 482 -- Median and mode

count=0 #initialise count
for movie_title in sort_year.original_title:
    count=count+len((movie_title.split())) #split wherever whitespace, add item to count
 #Here, Count is the Total number of words
print("Total number of words in movie titles in the given years=", count)
print("The average number of words in movie titles between the years 2000 to 2005=",round(count/482), "words.")
# Out:
# Total number of words in movie titles in the given years= 1296
# The average number of words in movie titles between the years 2000 to 2005= 3 words.

# %% [markdown]
# **3. What is the most common Genre for Vin Diesel & Emma Watson movies?**
# - 3.a) Vin Diesel

# %%
df_genres=pd.read_csv(file_path,index_col=3) #index col is genre
df_genres.fillna(value="False", inplace=True) #fill blanks with False
df_vin = df_genres['cast'].str.contains("Vin Diesel") #True wherever cast contains Vin Diesel

# %%
df_genres['cast'].str.contains('vin Diesel')
# Out:
# genres
# [{'id': 35, 'name': 'Comedy'}]                                                                                                    False
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]    False
# [{'id': 18, 'name': 'Drama'}]                                                                                                     False
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]                                                                     False
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]                                                                    False
#                                                                                                                                   ...
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]                                                                  False
# ...

# %%
df_vin.head()
# Out:
# genres
# [{'id': 35, 'name': 'Comedy'}]                                                                                                    False
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]    False
# [{'id': 18, 'name': 'Drama'}]                                                                                                     False
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]                                                                     False
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]                                                                    False
# Name: cast, dtype: bool

# %%
df_genres
# Out:
#                                                       id  \
# genres
# [{'id': 35, 'name': 'Comedy'}]                         1
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...     2
# [{'id': 18, 'name': 'Drama'}]                          3
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'na...     4
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name...     5
# ...                                                  ...
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'n...  2996
# [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'na...  2997
# [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name'...  2998
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'n...  2999
# [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'na...  3000
#
#                                                                                 belongs_to_collection  \
# genres
# [{'id': 35, 'name': 'Comedy'}]                      [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# ...

# %%
type(df_vin)
# Out:
# pandas.core.series.Series

# %%
df_vin[df_vin].index.values
# Out:
# array(["[{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 18, 'name': 'Drama'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]",
#        "[{'id': 28, 'name': 'Action'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 878, 'name': 'Science Fiction'}]",
# ...

# %%
df_vin=pd.DataFrame(df_vin) #to convert series to df
df_vin[0:100]
# Out:
#                                                      cast
# genres
# [{'id': 35, 'name': 'Comedy'}]                      False
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  False
# [{'id': 18, 'name': 'Drama'}]                       False
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'na...  False
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name...  False
# ...                                                   ...
# [{'id': 18, 'name': 'Drama'}]                       False
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name...  False
# [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'nam...  False
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...  False
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  False
#
# [100 rows x 1 columns]

# %%
df_vin = df_vin[df_vin['cast']==True]

# %%
df_vin
# Out:
#                                                     cast
# genres
# [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'nam...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name...  True
# [{'id': 18, 'name': 'Drama'}]                       True
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name...  True
# [{'id': 28, 'name': 'Action'}]                      True
# [{'id': 28, 'name': 'Action'}, {'id': 878, 'nam...  True
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name'...  True

# %%
df_vin=df_vin[df_vin["cast"]==True] #selecting rows(genres) where cast (Vin Diesel) is there (True)
df_vin
# Out:
#                                                     cast
# genres
# [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'nam...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name...  True
# [{'id': 18, 'name': 'Drama'}]                       True
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name...  True
# [{'id': 28, 'name': 'Action'}]                      True
# [{'id': 28, 'name': 'Action'}, {'id': 878, 'nam...  True
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name...  True
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name...  True
# [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name'...  True

# %%
df_vin_res = df_vin.groupby("genres")["cast"].sum().reset_index() #groups by "genre", takes sum of unique genres in df1 (where df1 contains genres where Vin Diesel is present
df_vin_res
# Out:
#                                               genres  cast
# 0  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...     1
# 1                      [{'id': 18, 'name': 'Drama'}]     1
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     1
# 3  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...     1
# 4  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...     1
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     2
# 6  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     1
# 7  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...     1
# 8                     [{'id': 28, 'name': 'Action'}]     1
# 9  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...     1

# %%
df_vin_res.loc[5,'genres']
# Out:
# "[{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]"

# %% [markdown]
# - b) Emma Watson

# %%
df_genres=pd.read_csv(file_path,index_col=3) #index col is genre
df_genres.fillna(value="False", inplace=True) #fill blanks with False
emma_watson = df_genres['cast'].str.contains("Emma Watson") #True wherever cast contains Vin Diesel

# %%
emma_watson[emma_watson].index.values
# Out:
# array(["[{'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10749, 'name': 'Romance'}]",
#        "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]",
#        "[{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]",
#        "[{'id': 18, 'name': 'Drama'}]",
#        "[{'id': 18, 'name': 'Drama'}, {'id': 12, 'name': 'Adventure'}]",
#        "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]"],
#       dtype=object)

# %%
type(emma_watson)
# Out:
# pandas.core.series.Series

# %%
emma_watson_df = pd.DataFrame(emma_watson)

# %%
emma_watson_df
# Out:
#                                                      cast
# genres
# [{'id': 35, 'name': 'Comedy'}]                      False
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  False
# [{'id': 18, 'name': 'Drama'}]                       False
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'na...  False
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name...  False
# ...                                                   ...
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'n...  False
# [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'na...  False
# [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name'...  False
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'n...  False
# [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'na...  False
#
# [3000 rows x 1 columns]

# %%
emma_watson_df[emma_watson_df['cast'] == True]
# Out:
#                                                     cast
# genres
# [{'id': 10751, 'name': 'Family'}, {'id': 14, 'n...  True
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...  True
# [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'na...  True
# [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name'...  True
# [{'id': 18, 'name': 'Drama'}]                       True
# [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name'...  True
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...  True

# %%
common_generes = emma_watson_df[emma_watson_df['cast'] == True].groupby('genres')['cast'].sum().reset_index()

# %%
common_generes
# Out:
#                                               genres  cast
# 0  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...     1
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...     2
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...     1
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...     1
# 4                      [{'id': 18, 'name': 'Drama'}]     1
# 5  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...     1

# %%
common_generes.loc[1,'genres']
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]"

# %% [markdown]
# **4. Which are the movies with the most and least earned
#
# 1.   List item
#
# 1.   List item
# 2.   List item
#
#
# 2.   List item
#
# revenue?**

# %%
df_revenue=pd.read_csv(file_path, index_col=0) #Read CSV
df_revenue.replace(0,np.nan, inplace=True) #Replace 0 values with na

df_revenue["revenue"]=df_revenue["revenue"].fillna(np.mean(df_revenue["revenue"])) #Replace na values with mean of Revenue
sort_least=df_revenue.sort_values("revenue", ascending=True) #Sort in ascending to find least earned revenue
sort_least.head(1)
# Out:
#     belongs_to_collection  budget  \
# id
# 348                   NaN   12.00
#
#                                                 genres homepage    imdb_id  \
# id
# 348  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN  tt0118172
#
#     original_language           original_title  \
# id
# 348                en  The Wind in the Willows
#
#                                               overview  popularity  \
# id
# 348  Jailed for his reckless driving, rambunctious ...        1.41
#
#                           poster_path  \
# id
# 348  /nsOM52BsDeHzc0yI27bah2OWems.jpg
#
#                             production_companies  \
# id
# 348  [{'name': 'Allied Filmmakers', 'id': 1755}]
#
#                                  production_countries release_date  runtime  \
# id
# 348  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     10/16/96    84.00
#
#                                       spoken_languages    status  \
# id
# ...

# %%
df_revenue = pd.read_csv(file_path ,index_col=0)
df_revenue.replace(0,np.nan,inplace = True)
df_revenue['revenue'] = df_revenue['revenue'].fillna(np.mean(df_revenue['revenue']))
df_budget = df_revenue.copy()

# %%
df_revenue.sort_values('revenue',ascending = False).head(1)
# Out:
#                                   belongs_to_collection         budget  \
# id
# 1127  [{'id': 86311, 'name': 'The Avengers Collectio... 220,000,000.00
#
#                                                  genres  \
# id
# 1127  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                homepage    imdb_id original_language  \
# id
# 1127  http://marvel.com/avengers_movie/  tt0848228                en
#
#      original_title                                           overview  \
# id
# 1127   The Avengers  When an unexpected enemy emerges and threatens...
#
#       popularity                       poster_path  \
# id
# 1127       89.89  /cezWGskPY5x7GaglTTRN4Fugfb8.jpg
#
#                                    production_companies  \
# id
# 1127  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                    production_countries release_date  runtime  \
# id
# 1127  [{'iso_3166_1': 'US', 'name': 'United States o...      4/25/12   143.00
# ...

# %% [markdown]
# movies with low and high budget

# %%
df_budget = df_revenue.copy()

df_budget['budget'].replace(0,np.nan,inplace = True)

df_budget['budget'] = df_budget['budget'].fillna(np.mean(df_budget['budget']))

df_budget.sort_values('budget',ascending=False).head(1)
# Out:
#                                   belongs_to_collection         budget  \
# id
# 2136  [{'id': 295, 'name': 'Pirates of the Caribbean... 380,000,000.00
#
#                                                  genres  \
# id
# 2136  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                homepage    imdb_id  \
# id
# 2136  http://disney.go.com/pirates/index-on-stranger...  tt1298650
#
#      original_language                               original_title  \
# id
# 2136                en  Pirates of the Caribbean: On Stranger Tides
#
#                                                overview  popularity  \
# id
# 2136  Captain Jack Sparrow crosses paths with a woma...       27.89
#
#                            poster_path  \
# id
# 2136  /wNUDAq5OUMOtxMlz64YaCp7gZma.jpg
#
#                                    production_companies  \
# id
# 2136  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
# ...

# %%
df_budget.sort_values('budget',ascending=True).head(1)
# Out:
#      belongs_to_collection  budget                         genres homepage  \
# id
# 1347                   NaN    1.00  [{'id': 18, 'name': 'Drama'}]      NaN
#
#         imdb_id original_language original_title  \
# id
# 1347  tt0048028                en   East of Eden
#
#                                                overview  popularity  \
# id
# 1347  In the Salinas Valley, in and around World War...        6.43
#
#                            poster_path  \
# id
# 1347  /hjH1uLOySpzgBdm1UQYjTV5yLav.jpg
#
#                         production_companies  \
# id
# 1347  [{'name': 'Warner Bros.', 'id': 6194}]
#
#                                    production_countries release_date  runtime  \
# id
# 1347  [{'iso_3166_1': 'US', 'name': 'United States o...       3/9/55   115.00
#
#                               spoken_languages    status  \
# id
# 1347  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline         title  \
# id
# ...

# %%
sort_most=df_revenue.sort_values("revenue", ascending=False)
sort_most.head(1)
# Out:
#                                   belongs_to_collection         budget  \
# id
# 1127  [{'id': 86311, 'name': 'The Avengers Collectio... 220,000,000.00
#
#                                                  genres  \
# id
# 1127  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                homepage    imdb_id original_language  \
# id
# 1127  http://marvel.com/avengers_movie/  tt0848228                en
#
#      original_title                                           overview  \
# id
# 1127   The Avengers  When an unexpected enemy emerges and threatens...
#
#       popularity                       poster_path  \
# id
# 1127       89.89  /cezWGskPY5x7GaglTTRN4Fugfb8.jpg
#
#                                    production_companies  \
# id
# 1127  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                    production_countries release_date  runtime  \
# id
# 1127  [{'iso_3166_1': 'US', 'name': 'United States o...      4/25/12   143.00
# ...

# %% [markdown]
# **5. What is the average runtime of movies in the year 2006?**

# %%
round(df_year.loc[2006,'runtime'].reset_index()['runtime'].mean())
# Out:
# 108

# %%
rt=df_year.loc[2006, ["runtime"]].reset_index() #Selecting row 2006 and column of interest (runtime)
rt=pd.DataFrame(rt) #Series to DF

rt
# Out:
#      year  runtime
# 0    2006    87.00
# 1    2006   118.00
# 2    2006    91.00
# 3    2006   144.00
# 4    2006   104.00
# ..    ...      ...
# 109  2006   117.00
# 110  2006   107.00
# 111  2006    94.00
# 112  2006    94.00
# 113  2006   113.00
#
# [114 rows x 2 columns]

# %%
run_time = rt["runtime"].mean()

# %%
round(run_time)
# Out:
# 108

# %% [markdown]
# ##Let us solve the another 5 questions

# %%
#creating a copy of orginal df
imdb_df_new = imdb_df.copy()

# %%
imdb_df_new.head(2)
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...        6.58
# 1  Mia Thermopolis is now a college graduate and ...        8.25
#
#                         poster_path  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg
#
# ...

# %%
imdb_df_new.shape
# Out:
# (3000, 24)

# %% [markdown]
# #Q1.Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
#checking for sanity in budget columns (outliers,vague values etc)
imdb_df_new.describe()
#budget of a movie in general cannot be 0 hence replacing those value with meadain
# Out:
#             id         budget  popularity  runtime          revenue  \
# count 3,000.00       2,188.00    3,000.00 2,986.00         3,000.00
# mean  1,500.50  30,893,054.08        8.46   108.29    66,725,851.89
# std     866.17  40,267,851.34       12.10    21.04   137,532,326.34
# min       1.00           1.00        0.00    11.00             1.00
# 25%     750.75   5,150,000.00        4.02    94.00     2,379,808.25
# 50%   1,500.50  16,000,000.00        7.37   104.00    16,807,068.00
# 75%   2,250.25  40,000,000.00       10.89   118.00    68,919,203.50
# max   3,000.00 380,000,000.00      294.34   338.00 1,519,557,910.00
#
#            Profit_Loss
# count         2,180.00
# mean     56,278,763.37
# std     128,776,612.59
# min    -107,447,384.00
# 25%      -1,639,452.25
# 50%      10,616,985.50
# 75%      62,106,940.00
# max   1,316,249,360.00

# %%
imdb_df_new[imdb_df_new['budget']==0].head(3)
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, Profit_Loss]
# Index: []

# %%
imdb_df_new.loc[imdb_df_new['budget'] < 1000 , 'budget'] = imdb_df_new['budget'].median()
imdb_df_new.loc[imdb_df_new['revenue'] < 1000 , 'revenue'] = imdb_df_new['revenue'].median()

# %%
imdb_df_new.describe()
# Out:
#             id         budget  popularity  runtime          revenue  \
# count 3,000.00       2,188.00    3,000.00 2,986.00         3,000.00
# mean  1,500.50  31,024,680.53        8.46   108.29    67,045,183.86
# std     866.17  40,192,699.70       12.10    21.04   137,396,426.58
# min       1.00       2,500.00        0.00    11.00         1,404.00
# 25%     750.75   5,988,000.00        4.02    94.00     2,947,600.00
# 50%   1,500.50  16,000,000.00        7.37   104.00    16,808,725.50
# 75%   2,250.25  40,000,000.00       10.89   118.00    68,919,203.50
# max   3,000.00 380,000,000.00      294.34   338.00 1,519,557,910.00
#
#            Profit_Loss
# count         2,180.00
# mean     56,278,763.37
# std     128,776,612.59
# min    -107,447,384.00
# 25%      -1,639,452.25
# 50%      10,616,985.50
# 75%      62,106,940.00
# max   1,316,249,360.00

# %%
#Replace extremely low values of budget and revenue column with median values of budget, revenue
imdb_df_new.loc[imdb_df_new['budget']<1000,'budget']= imdb_df_new['budget'].median()

imdb_df_new.loc[imdb_df_new['revenue']<1000,'revenue']= imdb_df_new['revenue'].median()

# %%
imdb_df_new.describe() #now fine
# Out:
#             id         budget  popularity  runtime          revenue  \
# count 3,000.00       2,188.00    3,000.00 2,986.00         3,000.00
# mean  1,500.50  31,024,680.53        8.46   108.29    67,045,183.86
# std     866.17  40,192,699.70       12.10    21.04   137,396,426.58
# min       1.00       2,500.00        0.00    11.00         1,404.00
# 25%     750.75   5,988,000.00        4.02    94.00     2,947,600.00
# 50%   1,500.50  16,000,000.00        7.37   104.00    16,808,725.50
# 75%   2,250.25  40,000,000.00       10.89   118.00    68,919,203.50
# max   3,000.00 380,000,000.00      294.34   338.00 1,519,557,910.00
#
#            Profit_Loss
# count         2,180.00
# mean     56,278,763.37
# std     128,776,612.59
# min    -107,447,384.00
# 25%      -1,639,452.25
# 50%      10,616,985.50
# 75%      62,106,940.00
# max   1,316,249,360.00

# %%
imdb_df_new['genres'].isnull().sum()
# Out:
# 7

# %%
imdb_df_new['profit'] = imdb_df_new['revenue'] -  imdb_df_new['budget']

# %%
#create profit and ROI column
# imdb_df_new['profit'] = imdb_df_new['revenue'] - imdb_df_new['budget']
imdb_df_new['roi']= round(100* (imdb_df_new['profit']/imdb_df_new['budget']))

# %%
high_revenue_movie = imdb_df_new.sort_values('profit',ascending = False).head(1).reset_index()
high_revenue_movie
# Out:
#    index    id                              belongs_to_collection  \
# 0   1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...
#
#           budget                          genres                  homepage  \
# 0 190,000,000.00  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/
#
#      imdb_id original_language original_title  \
# 0  tt2820852                en      Furious 7
#
#                                             overview  popularity  \
# 0  Deckard Shaw seeks revenge against Dominic Tor...       27.28
#
#                         poster_path  \
# 0  /dCgm7efXDmiABSdWDHBDBx2jwmn.jpg
#
#                                 production_companies  \
# 0  [{'name': 'Universal Pictures', 'id': 33}, {'n...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       4/1/15   137.00
#
#                            spoken_languages    status              tagline  \
# ...

# %%
actor_name = eval(high_revenue_movie.loc[0,'cast'])

# %%
high_profit_movie = imdb_df_new.sort_values('profit',ascending =False).head(1).reset_index()

# %%
high_profit_movie
# Out:
#    index    id                              belongs_to_collection  \
# 0   1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...
#
#           budget                          genres                  homepage  \
# 0 190,000,000.00  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/
#
#      imdb_id original_language original_title  \
# 0  tt2820852                en      Furious 7
#
#                                             overview  popularity  \
# 0  Deckard Shaw seeks revenge against Dominic Tor...       27.28
#
#                         poster_path  \
# 0  /dCgm7efXDmiABSdWDHBDBx2jwmn.jpg
#
#                                 production_companies  \
# 0  [{'name': 'Universal Pictures', 'id': 33}, {'n...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       4/1/15   137.00
#
#                            spoken_languages    status              tagline  \
# ...

# %%
high_profit_movie.crew.values
# Out:
# array(['[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director
# ...

# %%
director_list = []
producer_list = []
for i in crew_list:
  if i['job'] == 'Director':
   director_list.append(i['name'])
  if i['job'] == 'Producer':
   producer_list.append(i['name'])

# %%
print(producer_list,director_list)
# Out:
# ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell'] ['James Wan']

# %%
imdb_df_new.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
(imdb_df_new[imdb_df_new['profit'] == imdb_df_new['profit'].max()]).original_title
# Out:
# 1761    Furious 7
# Name: original_title, dtype: object

# %%
(imdb_df_new[imdb_df_new['profit'] == imdb_df_new['profit'].max()]).original_title.values
# Out:
# array(['Furious 7'], dtype=object)

# %%
imdb_df_new.loc[imdb_df_new['profit'].idxmax(),'original_title']
# Out:
# 'Furious 7'

# %%
max_profit_movie_df = imdb_df_new[imdb_df_new['profit'] == imdb_df_new['profit'].max()]

# %%
max_profit_movie_df
# Out:
#         id                              belongs_to_collection         budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou... 190,000,000.00
#
#                               genres                  homepage    imdb_id  \
# 1761  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#      original_language original_title  \
# 1761                en      Furious 7
#
#                                                overview  popularity  \
# 1761  Deckard Shaw seeks revenge against Dominic Tor...       27.28
#
#                            poster_path  \
# 1761  /dCgm7efXDmiABSdWDHBDBx2jwmn.jpg
#
#                                    production_companies  \
# 1761  [{'name': 'Universal Pictures', 'id': 33}, {'n...
#
#                                    production_countries release_date  runtime  \
# 1761  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       4/1/15   137.00
#
# ...

# %%
actor = (eval(max_profit_movie_df.cast.values[0]))[0]

# %%
actor
# Out:
# {'cast_id': 17,
#  'character': 'Dominic Toretto',
#  'credit_id': '5431dfd10e0a265915002c34',
#  'gender': 2,
#  'id': 12835,
#  'name': 'Vin Diesel',
#  'order': 0,
#  'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}

# %%
actor['name']
# Out:
# 'Vin Diesel'

# %%
crew_list = eval(max_profit_movie_df.crew.values[0])

# %%
crew_list[0:3]
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'}]

# %% [markdown]
# ### Name of the director and producer of the movie which made highest profit are:

# %%
crew_list[0]
# Out:
# {'credit_id': '52fe4cc8c3a36847f823e681',
#  'department': 'Production',
#  'gender': 2,
#  'id': 12835,
#  'job': 'Producer',
#  'name': 'Vin Diesel',
#  'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}

# %%
def convert_to_list(str):
  return eval(str)

# %%
crew_list = eval(high_profit_movie.loc[0,'crew'])

# %%
producer_list=[]
director_list=[]
for elem in crew_list:
  if elem['job']=='Producer':
    producer_list.append(elem['name'])
  if elem['job']=='Director':
    director_list.append(elem['name'])

# %%
print(f'PRODUCERS : {producer_list}')
print(f'DIRECTORS : {director_list}')
# Out:
# PRODUCERS : ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']
# DIRECTORS : ['James Wan']

# %% [markdown]
# ###Actors in the Highest profit movie

# %%
type(eval(high_profit_movie.loc[0,'crew']))
# Out:
# list

# %%
crew_list = eval(high_profit_movie.loc[0,'crew'])

# %%
type(crew_list)
# Out:
# list

# %%
actor_list = []
for ele in crew_list:
  actor_list.append(ele['name'])

# %%
len(actor_list)
# Out:
# 98

# %%
actor_dict = (eval(high_profit_movie.cast.values[0]))
actor_dict
# Out:
# [{'cast_id': 17,
#   'character': 'Dominic Toretto',
#   'credit_id': '5431dfd10e0a265915002c34',
#   'gender': 2,
#   'id': 12835,
#   'name': 'Vin Diesel',
#   'order': 0,
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'cast_id': 19,
#   'character': "Brian O'Conner",
#   'credit_id': '5431dfe4c3a3681143002b98',
#   'gender': 2,
#   'id': 8167,
#   'name': 'Paul Walker',
#   'order': 1,
#   'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'},
#  {'cast_id': 18,
#   'character': 'Hobbs',
#   'credit_id': '5431dfdbc3a36831a6004376',
#   'gender': 2,
#   'id': 18918,
#   'name': 'Dwayne Johnson',
#   'order': 2,
#   'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'},
#  {'cast_id': 20,
#   'character': 'Letty',
#   'credit_id': '5431dfeec3a36811ef002c75',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 3,
#   'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'},
#  {'cast_id': 28,
#   'character': 'Roman',
# ...

# %%
actor_list=[]
for elem in actor_dict:
  actor_list.append(elem['name'])

# %%
#actors
print(f'Actors of the movie are :')
actor_list
# Out:
# Actors of the movie are :
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calder√≥n',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
# ...

# %% [markdown]
# #Q2.This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
imdb_df_new
# Out:
#         id                              belongs_to_collection        budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2        3                                                NaN  3,300,000.00
# 3        4                                                NaN  1,200,000.00
# 4        5                                                NaN           NaN
# ...    ...                                                ...           ...
# 2995  2996                                                NaN           NaN
# 2996  2997                                                NaN           NaN
# 2997  2998                                                NaN 65,000,000.00
# 2998  2999                                                NaN 42,000,000.00
# 2999  3000                                                NaN 35,000,000.00
#
# ...

# %%
imdb_df_new['roi'] = round(100*imdb_df_new['profit'] / imdb_df_new['budget'])

# %%
high_lan_roi  =imdb_df_new.groupby('original_language')['roi'].mean().reset_index().sort_values('roi',ascending = False).head(10)
high_lan_roi
# Out:
#    original_language       roi
# 18                ko 20,550.91
# 6                 el  5,198.00
# 28                sr  3,261.00
# 7                 en  1,238.01
# 32                tr    966.00
# 5                 de    807.64
# 12                he    456.00
# 31                te    440.00
# 35                zh    408.43
# 9                 fa    400.00

# %%
print('the highest roi language is ',high_lan_roi.iloc[0,0])
# Out:
# the highest roi language is  ko

# %%
#Use groupby function on movie languages and ROI and finding mean
lang_roi = imdb_df_new.groupby('original_language')['roi'].mean()
lang_roi
# Out:
# original_language
# ar         NaN
# bn         NaN
# cn      174.00
# cs         NaN
# da      191.50
# de      807.64
# el    5,198.00
# en    1,238.01
# es      379.41
# fa      400.00
# fi      -30.00
# fr      170.56
# he      456.00
# hi      271.41
# hu      -87.00
# id      -42.00
# it       77.15
# ja      185.89
# ko   20,550.91
# ml      370.50
# mr      193.00
# nb       19.00
# nl       34.00
# no      148.00
# pl      395.50
# pt        5.25
# ro      -49.67
# ru      248.82
# sr    3,261.00
# sv      115.00
# ta      200.54
# te      440.00
# tr      966.00
# ur      351.00
# vi      -51.00
# zh      408.43
# Name: roi, dtype: float64

# %%
lang_roi = lang_roi.reset_index()

# %%
lang_roi.head()
# Out:
#   original_language    roi
# 0                ar    NaN
# 1                bn    NaN
# 2                cn 174.00
# 3                cs    NaN
# 4                da 191.50

# %%
lang_roi.sort_values(by='roi',ascending=False).head(3)
# Out:
#    original_language       roi
# 18                ko 20,550.91
# 6                 el  5,198.00
# 28                sr  3,261.00

# %%
print('Language with highest average roi is')
imdb_df_new.groupby('original_language')['roi'].mean().reset_index().sort_values(by='roi',ascending=False).iloc[0,0]
# Out:
# Language with highest average roi is
# 'ko'

# %% [markdown]
# #Q3.Find out the unique genres of movies in this dataset.

# %%
imdb_df_new
# Out:
#         id                              belongs_to_collection        budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2        3                                                NaN  3,300,000.00
# 3        4                                                NaN  1,200,000.00
# 4        5                                                NaN           NaN
# ...    ...                                                ...           ...
# 2995  2996                                                NaN           NaN
# 2996  2997                                                NaN           NaN
# 2997  2998                                                NaN 65,000,000.00
# 2998  2999                                                NaN 42,000,000.00
# 2999  3000                                                NaN 35,000,000.00
#
# ...

# %%
no_null_genres = imdb_df_new[~imdb_df_new['genres'].isna()]

# %%
no_null_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2993 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2993 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 2183 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               945 non-null    object
#  5   imdb_id                2993 non-null   object
#  6   original_language      2993 non-null   object
#  7   original_title         2993 non-null   object
#  8   overview               2985 non-null   object
#  9   popularity             2993 non-null   float64
#  10  poster_path            2992 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2941 non-null   object
#  13  release_date           2993 non-null   object
# ...

# %%
#considering only those rows in genres column which have no null values
no_na_genres = imdb_df_new[~imdb_df_new['genres'].isna()]

# %%
len(no_na_genres)
# Out:
# 2993

# %%
no_null_genres.loc[1,'genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]"

# %%
no_na_genres.loc[1,'genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]"

# %%
no_na_genres.loc[4,'genres']
# Out:
# "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]"

# %%
no_na_genres.head(1)
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity                       poster_path  \
# 0        6.58  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15    93.00
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
# ...

# %%
no_na_genres.loc[1,'genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]"

# %%
type(no_na_genres)
# Out:
# pandas.core.frame.DataFrame

# %%
no_null_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2993 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2993 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 2183 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               945 non-null    object
#  5   imdb_id                2993 non-null   object
#  6   original_language      2993 non-null   object
#  7   original_title         2993 non-null   object
#  8   overview               2985 non-null   object
#  9   popularity             2993 non-null   float64
#  10  poster_path            2992 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2941 non-null   object
#  13  release_date           2993 non-null   object
# ...

# %%
genre_list = []
for i,j in no_null_genres.iterrows():
  z =eval( no_null_genres.loc[i,'genres'])
  for ele in z:
    genre_list.append(ele['name'])

# %%
unique_genres = pd.DataFrame(set(genre_list))
unique_genres
# Out:
#                   0
# 0           Romance
# 1         Animation
# 2             Crime
# 3         Adventure
# 4          Thriller
# 5           Fantasy
# 6            Family
# 7           Foreign
# 8             Drama
# 9           Mystery
# 10              War
# 11      Documentary
# 12         TV Movie
# 13            Music
# 14          Western
# 15          History
# 16           Action
# 17           Comedy
# 18           Horror
# 19  Science Fiction

# %%
name_test = ['Ravi','Ranjan','Alma Better', 'Data Science']

list(enumerate(name_test))
# Out:
# [(0, 'Ravi'), (1, 'Ranjan'), (2, 'Alma Better'), (3, 'Data Science')]

# %%
#create a list of genres and using .iterrow() method to iterate over genres column 
# .iterrow() --->> same as enumerate() its compulsory to use it in case of DataFrame
gen_list=[]
for index,row in no_null_genres.iterrows():
  genre = eval(no_null_genres.loc[index,'genres'])
  for movie_genre in genre:
    gen_list.append(movie_genre['name'])
  
#unique list of genres are:
pd.DataFrame(set(gen_list),columns=['Unique Genres'])
# Out:
#       Unique Genres
# 0           Romance
# 1         Animation
# 2             Crime
# 3         Adventure
# 4          Thriller
# 5           Fantasy
# 6            Family
# 7           Foreign
# 8             Drama
# 9           Mystery
# 10              War
# 11      Documentary
# 12         TV Movie
# 13            Music
# 14          Western
# 15          History
# 16           Action
# 17           Comedy
# 18           Horror
# 19  Science Fiction

# %% [markdown]
# #Q4.Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
imdb_df_pd_roi = imdb_df_new.copy()

# %%
#create profit and ROI column
imdb_df_pd_roi['profit'] = imdb_df_pd_roi['revenue'] - imdb_df_pd_roi['budget']
imdb_df_pd_roi['roi']= round(100* (imdb_df_pd_roi['profit']/imdb_df_pd_roi['budget']))

# %%
imdb_df_pd_roi.head(1)
# Out:
#    id                              belongs_to_collection        budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity                       poster_path  \
# 0        6.58  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15    93.00
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
# ...

# %%
imdb_df_pd_roi.sort_values(['roi'],ascending=False)
# Out:
#         id                              belongs_to_collection     budget  \
# 1230  1231  [{'id': 41437, 'name': 'Paranormal Activity Co...  15,000.00
# 1679  1680  [{'id': 64750, 'name': 'Blair Witch Collection...  60,000.00
# 2610  2611                                                NaN   5,000.00
# 1893  1894                                                NaN  12,000.00
# 817    818                                                NaN 100,000.00
# ...    ...                                                ...        ...
# 2989  2990                                                NaN        NaN
# 2990  2991                                                NaN        NaN
# 2994  2995                                                NaN        NaN
# 2995  2996                                                NaN        NaN
# 2996  2997                                                NaN        NaN
#
#                                                  genres  \
# ...

# %%
def convert_to_list(str):
  return eval(str)

# %%
imdb_df_pd_roi = imdb_df_pd_roi.reset_index()

# %%
#considering only those rows in crew column which have no null values
no_na_crew = imdb_df_pd_roi[~imdb_df_pd_roi['crew'].isna()]
type(no_na_crew)
# Out:
# pandas.core.frame.DataFrame

# %%
no_na_crew.loc[~no_na_crew['crew'].isna(),'crew']=no_na_crew.loc[~no_na_crew['crew'].isna(),'crew'].apply(convert_to_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
type(no_na_crew)
# Out:
# pandas.core.frame.DataFrame

# %%
no_na_crew.shape
# Out:
# (2984, 27)

# %%
crew_list=no_na_crew.loc[0,'crew']

# %%
type(crew_list)
# Out:
# list

# %%
producer_list=[]
for elem in crew_list:
     if elem['job']=='Producer':
        producer_list.append(elem['name'])
print(producer_list)
# Out:
# ['Andrew Panay']

# %%
#A simple function to extract list of all producers for a given movie_index
def create_producer_list(index):
  # movie_index = no_na_crew.iloc[index]
  crew_list= no_na_crew.loc[index,'crew']
  producer_list=[]
  for elem in crew_list:
     if elem['job']=='Producer':
        producer_list.append(elem['name'])
  return producer_list

# %%
create_producer_list(10)
# Out:
# ['Irwin Winkler', 'Robert Chartoff']

# %%
#A simple function to extract names of all directors for a given movie_index
#each movie has only one director
def create_director(index):
  # movie_index = no_na_crew.iloc[index]
  crew_list= no_na_crew.loc[index,'crew']

  for elem in crew_list:
     if elem['job']=='Director':
        return elem['name']

# %%
create_director(10)
# Out:
# 'John G. Avildsen'

# %%
#create a empty DataFrame with required Column names in which we will append data later
Table = pd.DataFrame(columns=['Movie Title','Producers','Directors','ROI'])

# %% [markdown]
# ####appending in Table Df and using Try Except block to bypass error because some values of the crew dictionaries contain float as value

# %%
for index,row in no_na_crew.iterrows():
  
  try:
      Table = Table.append({'Movie Title':no_na_crew.loc[index,'original_title'],'Producers':create_producer_list(index),'Directors':create_director(index),'ROI':no_na_crew.loc[index,'roi']},ignore_index=True)
  except:
    continue

# %% [markdown]
# ###Table containing columns of Movie Title,its Producers, Directors and ROI

# %%
Table.head()
# Out:
#                                 Movie Title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                            Producers        Directors      ROI
# 0                                     [Andrew Panay]       Steve Pink   -12.00
# 1  [Whitney Houston, Mario Iscovich, Debra Martin...   Garry Marshall   138.00
# 2  [David Lancaster, Michel Litvak, Jason Blum, H...  Damien Chazelle   297.00
# 3                                      [Sujoy Ghosh]      Sujoy Ghosh 1,233.00
# 4                                                 []   Jong-seok Yoon      NaN

# %%
(Table.sort_values('ROI', ascending=False)).head(3)
# Out:
#                   Movie Title                            Producers  \
# 1225      Paranormal Activity  [Jason Blum, Oren Peli, Amir Zbeda]
# 1672  The Blair Witch Project            [Robin Cowie, Gregg Hale]
# 2597                       대호                                   []
#
#            Directors          ROI
# 1225       Oren Peli 1,288,939.00
# 1672   Daniel Myrick   413,233.00
# 2597  Park Hoon-Jung   221,569.00

# %% [markdown]
# #Q5.Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %%
#considering only those rows in cast column which have no null values
no_na_cast = (imdb_df_pd_roi[~imdb_df_pd_roi['cast'].isna()]).reset_index()

# %%
type(eval(no_na_cast.loc[0,'cast']))
# Out:
# list

# %%
actors_list = []
for i,j in no_na_cast.iterrows():
  for ele in eval(no_na_cast.loc[i,'cast']):
    if type(ele) == dict:
      actors_list.append(ele['name'])

# %%
actor_df  = pd.DataFrame(actors_list,columns=['Name_of_Actor']).reset_index()

# %%
actor_df.shape
# Out:
# (61811, 2)

# %%
actor_df.Name_of_Actor.nunique()
# Out:
# 38588

# %%
actor_df.head()
# Out:
#    index   Name_of_Actor
# 0      0     Rob Corddry
# 1      1  Craig Robinson
# 2      2      Clark Duke
# 3      3      Adam Scott
# 4      4     Chevy Chase

# %%
#sorting the actors using groupby function
actor_df.Name_of_Actor.value_counts().reset_index().head()
# Out:
#                index  Name_of_Actor
# 0     Robert De Niro             30
# 1  Samuel L. Jackson             30
# 2     Morgan Freeman             27
# 3       Bruce Willis             25
# 4       J.K. Simmons             25

# %% [markdown]
# ###Actors who have done maximum movies are:

# %%
print('Samuel L. Jackson and Robert De Niro both have done 30 films')
# Out:
# Samuel L. Jackson and Robert De Niro both have done 30 films

# %%
profit1=[]
profit2=[]
movie1=[]
movie2=[]
for index,row in no_na_cast.iterrows():
  for iter in no_na_cast.loc[index,'cast']:
    if type(iter)== dict:
      actor= iter['name']
      if 'Robert De Niro' in actor:
        profit1.append(no_na_cast.loc[index,'profit'])
        movie1.append(no_na_cast.loc[index,'original_title'])
      
        
      if 'Samuel L. Jackson' in actor:
        profit2.append(no_na_cast.loc[index,'profit'])
        movie2.append(no_na_cast.loc[index,'original_title'])

# %%
#creating a loop to get the genres for Robert and Samuel
gener_r=[]
a=[]
for i in range(len(movie1)):
  for g in no_na_cast.loc[i,'genres']:
    a.append(g['name'])
    
  gener_r.append(a)
  a=[]

gener_s=[]
b=[]
for i in range(len(movie2)):
  for g in no_na_cast.loc[i,'genres']:
    b.append(g['name'])
    
  gener_s.append(b)
  b=[]

# %%
genr = np.array(gener_r)
gens = np.array(gener_s)

# %%
#creating sub dataframe for Robert
mov1= pd.DataFrame(movie1,columns=['Movie Name'])
prof1=pd.DataFrame(profit1,columns=['Movie Profit'])
gen1= pd.DataFrame(genr.flatten(),columns=['Genres'])

# %%
Movies_by_Robert=pd.concat([mov1,gen1,prof1],axis=1)

# %%
Movies_by_Robert.head(2)
# Out:
# Empty DataFrame
# Columns: [Movie Name, Genres, Movie Profit]
# Index: []

# %% [markdown]
# ##Movies by Robert De Niro

# %%
Movies_by_Robert.sort_values(by='Movie Profit',ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [Movie Name, Genres, Movie Profit]
# Index: []

# %%
#creating sub dataframe for Samuel
mov2= pd.DataFrame(movie2,columns=['Movie Name'])
prof2=pd.DataFrame(profit2,columns=['Movie Profit'])
gen2= pd.DataFrame(gens.flatten(),columns=['Genres'])

# %%
Movies_by_Samuel=pd.concat([mov1,gen1,prof1],axis=1)

# %% [markdown]
# ###Movies by Samuel L jackson

# %%
Movies_by_Samuel.sort_values(by='Movie Profit',ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [Movie Name, Genres, Movie Profit]
# Index: []

# %% [markdown]
# #Q6) Top 3 directors prefer which actors the most?

# %%
imdb_df_pd_roi.head()
# Out:
#    index  id                              belongs_to_collection        budget  \
# 0      0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ... 14,000,000.00
# 1      1   2  [{'id': 107674, 'name': 'The Princess Diaries ... 40,000,000.00
# 2      2   3                                                NaN  3,300,000.00
# 3      3   4                                                NaN  1,200,000.00
# 4      4   5                                                NaN           NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# ...

# %%
#considering only those rows in crew column which have no null values
imdb_dirc_df = imdb_df_pd_roi[~imdb_df_pd_roi['crew'].isna()]

# %%
def get_actors(index):
  actor_list=[]
  movie_index = imdb_dirc_df.iloc[index]
  cast_list= movie_index.loc['cast']
  for iter in cast_list:
    if type(iter)== dict:
      actor= iter['name']
      actor_list.append(actor)
  return actor_list

# %%
#A simple function to extract list of all directors for a given movie_index
def get_director(index):
  movie_index = imdb_dirc_df.iloc[index]
  crew_list= movie_index.loc['crew']

  for elem in crew_list:
     if elem['job']=='Director':
        return elem['name']

# %%
get_actors(1)
# Out:
# []

# %%
get_director(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-302-6a2f38ff69d0> in <module>
# ----> 1 get_director(1)
#
# <ipython-input-300-2f421f5cd181> in get_director(index)
#       5
#       6   for elem in crew_list:
# ----> 7      if elem['job']=='Director':
#       8         return elem['name']
#
# TypeError: string indices must be integers

# %%
#create a empty DataFrame with required Column names in which we will append data later
Table_dirc = pd.DataFrame(columns=['Directors','Actors'])

# %%
for index,row in imdb_dirc_df.iterrows():
  
  try:
      Table_dirc = Table_dirc.append({'Directors':get_director(index),'Actors':get_actors(index)},ignore_index=True)
  except:
    continue

# %%
Table_dirc.shape
# Out:
# (0, 2)

# %%
Table_dirc.head()

# %%
(Table_dirc.Directors.value_counts().rename_axis('unique_values').reset_index(name='counts')).head(3)

# %%
df_top_3_dric = Table_dirc[Table_dirc['Directors'].isin(['Ron Howard','Clint Eastwood','Steven Spielberg'])]

# %%
df_top_3_dric.shape

# %%
df_top_3_dric.head()

# %%
actor_list = []
for index,row in df_top_3_dric.iterrows():
  actor_list.append(df_top_3_dric.loc[index,'Actors'])

# %%
flat_list = [item for sublist in actor_list for item in sublist]

# %%
result = [["Ravi","Ranjan"], ["Ravi", "Ram"], ["Shyam", "Priya"]]

# %%
flat_list = [item for sublist in result for item in sublist]

# %%
flat_list
# Out:
# ['Ravi', 'Ranjan', 'Ravi', 'Ram', 'Shyam', 'Priya']

# %%
print('Top 3 directors prefer most the actor is ' + max(set(flat_list), key=flat_list.count))
# Out:
# Top 3 directors prefer most the actor is Ravi

# %%
actors_list_ron = []
actors_list_clint = []
actors_list_steven = []
for index,row in df_top_3_dric.iterrows():
  if df_top_3_dric.loc[index,'Directors'] == 'Ron Howard':
    actors_list_ron.append(df_top_3_dric.loc[index,'Actors'])
  if df_top_3_dric.loc[index,'Directors'] == 'Clint Eastwood':
    actors_list_clint.append(df_top_3_dric.loc[index,'Actors'])
  if df_top_3_dric.loc[index,'Directors'] == 'Steven Spielberg':
    actors_list_steven.append(df_top_3_dric.loc[index,'Actors'])

# %%
flat_list_ron = [item for sublist in actors_list_ron for item in sublist]
flat_list_clint = [item for sublist in actors_list_clint for item in sublist]
flat_list_steven = [item for sublist in actors_list_steven for item in sublist]

# %%
print('Ron Howard director prefer most the actor is ' + max(set(flat_list_ron), key=flat_list_ron.count))

# %%
print('Clint Eastwood director prefer most the actor is ' + max(set(flat_list_clint), key=flat_list_clint.count))

# %%
print('Steven Spielberg director prefer most the actor is ' + max(set(flat_list_steven), key=flat_list_steven.count))
